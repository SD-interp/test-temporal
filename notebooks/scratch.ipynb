# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv(r"C:\Users\91967\Downloads\expanded_NOF_selected_acts_layer_out_21_pls.csv")

# %%
fig = px.scatter_3d(df, x="pls_1", y="pls_3", z="pls_4", color="log10_time_horizon_months")
fig.update_traces(marker={"size":1})
